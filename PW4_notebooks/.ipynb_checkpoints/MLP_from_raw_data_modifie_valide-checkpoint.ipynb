# %% [markdown]
# # Multilayer Perceptron from raw data
# This notebook will guide you through the use of the `keras` package to train a multilayer perceptron for handwritten digits classification. You are going to use the `mnist` dataset from LeCun et al. 1998

# %% [markdown]
# ## Loading the packages

# %%
#%pip install tensorflow --upgrade
#%pip install keras --upgrade

import numpy as np
from matplotlib import pyplot as pl

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from sklearn import metrics as me

# %matplotlib inline

# %% [markdown]
# ## Using raw data to train a MLP
# First load the `mnist` dataset and normalize it to be in the range [0, 1]

# %%
from tensorflow.keras.utils import to_categorical

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

n_classes = 10
# convert class vectors to binary class matrices
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %%
from tensorflow.keras.datasets import mnist

# Chargement des données
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Mise à plat des images 28x28 -> 784
x_train = x_train.reshape(-1, 28*28).astype('float32') / 255
x_test = x_test.reshape(-1, 28*28).astype('float32') / 255

# One-hot encoding des labels
y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

def build_mlp_model(hidden_units):
    model = Sequential()
    model.add(Dense(hidden_units, activation='relu', input_shape=(784,)))
    model.add(Dense(10, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model = Sequential()
model.add(Input(shape=(784,)))
model.add(Dense(2, activation='sigmoid'))
#model.add(Dropout(0.5))
model.add(Dense(n_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 2)                   │           1,570 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │              30 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,600 (6.25 KB)
#  Trainable params: 1,600 (6.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Define some constants and train the MLP

# %%
import matplotlib.pyplot as plt

histories = {}
for units in [128, 256, 512]:
    print(f"Training model with {units} hidden units...")
    model = build_mlp_model(units)
    history = model.fit(x_train, y_train_cat, epochs=10, batch_size=128, validation_split=0.1, verbose=0)
    histories[units] = (model, history)
# Out:
# Training model with 128 hidden units...
# C:\Users\natha\anaconda3\envs\ARN\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training model with 256 hidden units...
# Training model with 512 hidden units...

# %%
batch_size = 128
n_epoch = 3

model.compile(loss='categorical_crossentropy', optimizer=RMSprop(), metrics=['accuracy'])

history = model.fit(X_train, Y_train,
                    batch_size=batch_size, epochs=n_epoch,
                    verbose=1, validation_split=0.1)
# Out:
# Epoch 1/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9988 - loss: 0.0065 - val_accuracy: 0.9817 - val_loss: 0.0691
# Epoch 2/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9994 - loss: 0.0042 - val_accuracy: 0.9863 - val_loss: 0.0630
# Epoch 3/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9996 - loss: 0.0026 - val_accuracy: 0.9837 - val_loss: 0.0659

# %%
for units, (_, history) in histories.items():
    plt.plot(history.history['val_accuracy'], label=f'{units} units')

plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
pl.plot(history.history['loss'], label='Training')
pl.plot(history.history['val_loss'], label='Testing')
pl.legend()
pl.grid()

score = model.evaluate(X_test, Y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.06430567800998688
# Test accuracy: 0.9825999736785889

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

best_model = histories[512][0]  # à adapter selon les résultats obtenus
y_pred = best_model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Matrice de confusion
cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(cm, display_labels=range(10))
disp.plot(cmap='Blues')
plt.title("Matrice de confusion finale")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step

# %%
from sklearn.metrics import confusion_matrix

pred = model.predict(X_test)
pred = np.argmax(pred, axis=-1)
confusion_matrix(y_test, pred)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# array([[ 970,    1,    1,    0,    1,    0,    2,    1,    3,    1],
#        [   0, 1123,    2,    2,    0,    1,    2,    2,    3,    0],
#        [   1,    0, 1012,    5,    1,    0,    2,    3,    7,    1],
#        [   0,    0,    1,  994,    0,    3,    0,    2,    2,    8],
#        [   0,    0,    4,    1,  959,    0,    2,    2,    1,   13],
#        [   2,    0,    0,    9,    1,  870,    3,    0,    6,    1],
#        [   4,    3,    1,    1,    2,    3,  944,    0,    0,    0],
#        [   0,    4,    6,    3,    0,    0,    0, 1009,    3,    3],
#        [   2,    0,    4,    3,    2,    1,    1,    3,  953,    5],
#        [   2,    2,    0,    2,    3,    1,    0,    6,    1,  992]],
#       dtype=int64)
